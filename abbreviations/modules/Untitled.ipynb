# %%
import json
import os
import sys
sys.path.append("../")
sys.path.append("../../")
sys.path.append("../modules/")
import modules.common_helper as cm_help
from ibm_watson import DiscoveryV1
import modules.config as config
import modules.discovery_helper as dh 

import os
import time
from pprint import pprint
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

all_params = cm_help.get_params()
COLLECTION_NAME = config.DISCOVERY_COLLECTION_NAME
discovery_data = dh.discovery_init(COLLECTION_NAME=COLLECTION_NAME)
dh.processDirectory('corpus',discovery_data)
# Out:
# Discovery instance loaded a1
# COLLECTION ID: 0ee15f74-a6b0-4b9f-8de3-57f1e7490ec7 COLLECTION NAME: Test
# 'attempt no 0'
#
# Processing dir corpus with 1 files
#
# 'attempt no 1'
#
# Processing dir corpus with 0 files
#
# 'attempt no 2'
#
# Processing dir corpus with 0 files
#
# 'attempt no 3'
#
# Processing dir corpus with 0 files
#
# 'attempt no 4'
#
# Processing dir corpus with 0 files
#
# 'attempt no 5'
#
# Processing dir corpus with 0 files
#
# 'attempt no 6'
#
# Processing dir corpus with 6 files
#
# 'attempt no 7'
#
# Processing dir corpus with 0 files
#
# 'attempt no 8'
#
# Processing dir corpus with 0 files
#
# 'attempt no 9'
#
# Processing dir corpus with 0 files
#
# 'attempt no 10'
#
# Processing dir corpus with 0 files
#
# 'attempt no 11'
#
# Processing dir corpus with 0 files
#
# 'attempt no 12'
#
# Processing dir corpus with 0 files
#
# 'attempt no 13'
#
# Processing dir corpus with 0 files
#
# 'attempt no 14'
#
# Processing dir corpus with 0 files
#
# 'attempt no 15'
#
# Processing dir corpus with 0 files
#
# 'attempt no 16'
#
# Processing dir corpus with 0 files
#
# 'attempt no 17'
#
# Processing dir corpus with 0 files
#
# 'attempt no 18'
#
# Processing dir corpus with 0 files
#
# 'attempt no 19'
#
# Processing dir corpus with 0 files
#
# 'attempt no 20'
#
# Processing dir corpus with 0 files
#
# 'attempt no 21'
#
# Processing dir corpus with 0 files
#
# 'attempt no 22'
#
# Processing dir corpus with 0 files
#
# 'attempt no 23'
#
# Processing dir corpus with 0 files
#
# 'attempt no 24'
#
# Processing dir corpus with 0 files
#
# 'attempt no 25'
#
# Processing dir corpus with 0 files
#
# 'attempt no 26'
#
# Processing dir corpus with 0 files
#
# 'attempt no 27'
#
# Processing dir corpus with 0 files
#
# 'attempt no 28'
#
# Processing dir corpus with 0 files
#
# 'attempt no 29'
#
# Processing dir corpus with 0 files
#
# 'attempt no 30'
#
# Processing dir corpus with 0 files
#
# 'attempt no 31'
#
# Processing dir corpus with 0 files
#
# 'attempt no 32'
#
# Processing dir corpus with 0 files
#
# 'attempt no 33'
#
# Processing dir corpus with 0 files
#
# 'attempt no 34'
#
# Processing dir corpus with 0 files
#
# 'attempt no 35'
#
# Processing dir corpus with 0 files
#
# 'attempt no 36'
#
# Processing dir corpus with 0 files
#
# 'attempt no 37'
#
# Processing dir corpus with 0 files
#
# 'attempt no 38'
#
# Processing dir corpus with 0 files
#
# 'attempt no 39'
#
# Processing dir corpus with 0 files
#
# 'attempt no 40'
#
# Processing dir corpus with 0 files
#
# 'attempt no 41'
#
# Processing dir corpus with 0 files
#
# 'attempt no 42'
#
# Processing dir corpus with 0 files
#
# 'attempt no 43'
#
# Processing dir corpus with 0 files
#
# 'attempt no 44'
#
# Processing dir corpus with 0 files
#
# 'attempt no 45'
#
# Processing dir corpus with 0 files
#
# 'attempt no 46'
#
# Processing dir corpus with 0 files
#
# 'attempt no 47'
#
# Processing dir corpus with 0 files
#
# 'attempt no 48'
#
# Processing dir corpus with 0 files
#
# 'attempt no 49'
#
# Processing dir corpus with 0 files
